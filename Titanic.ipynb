# %%
import pandas as pd
import seaborn as sns

# %%
RMS = pd.read_csv("https://milliams.com/courses/data_analysis_python/titanic.csv")
RMS
# Out:
#                                 name  gender   age             class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0               3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0               3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0               3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0               3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0               3rd        S
# ...                              ...     ...   ...               ...      ...
# 2202                Wynn, Mr. Walter    male  41.0         deck crew        B
# 2203             Yearsley, Mr. Harry    male  40.0  victualling crew        S
# 2204        Young, Mr. Francis James    male  32.0  engineering crew        S
# 2205             Zanetti, Sig. Minio    male  20.0  restaurant staff        S
# 2206              Zarracchi, Sig. L.    male  26.0  restaurant staff        S
#
# ...

# %%
RMS["age"]
# Out:
# 0       42.0
# 1       13.0
# 2       16.0
# 3       39.0
# 4       16.0
#         ...
# 2202    41.0
# 2203    40.0
# 2204    32.0
# 2205    20.0
# 2206    26.0
# Name: age, Length: 2207, dtype: float64

# %%
RMS["age"].mean()
# Out:
# 30.436734693877504

# %%
male_filter = RMS["gender"] == "male"
male_filter
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2202     True
# 2203     True
# 2204     True
# 2205     True
# 2206     True
# Name: gender, Length: 2207, dtype: bool

# %%
RMS[male_filter]
# Out:
#                                name gender   age             class embarked  \
# 0               Abbing, Mr. Anthony   male  42.0               3rd        S
# 1         Abbott, Mr. Eugene Joseph   male  13.0               3rd        S
# 2       Abbott, Mr. Rossmore Edward   male  16.0               3rd        S
# 5     Abelseth, Mr. Olaus Jørgensen   male  25.0               3rd        S
# 6               Abelson, Mr. Samuel   male  30.0               2nd        C
# ...                             ...    ...   ...               ...      ...
# 2202               Wynn, Mr. Walter   male  41.0         deck crew        B
# 2203            Yearsley, Mr. Harry   male  40.0  victualling crew        S
# 2204       Young, Mr. Francis James   male  32.0  engineering crew        S
# 2205            Zanetti, Sig. Minio   male  20.0  restaurant staff        S
# 2206             Zarracchi, Sig. L.   male  26.0  restaurant staff        S
#
# ...

# %%
RMS[male_filter]["age"].mean()
# Out:
# 30.83231351981346

# %%
male_filter_age = RMS[male_filter]["age"]
male_filter_age
# Out:
# 0       42.0
# 1       13.0
# 2       16.0
# 5       25.0
# 6       30.0
#         ...
# 2202    41.0
# 2203    40.0
# 2204    32.0
# 2205    20.0
# 2206    26.0
# Name: age, Length: 1718, dtype: float64

# %% [markdown]
# #Filtering

# %%
RMS
# Out:
#                                 name  gender   age             class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0               3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0               3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0               3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0               3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0               3rd        S
# ...                              ...     ...   ...               ...      ...
# 2202                Wynn, Mr. Walter    male  41.0         deck crew        B
# 2203             Yearsley, Mr. Harry    male  40.0  victualling crew        S
# 2204        Young, Mr. Francis James    male  32.0  engineering crew        S
# 2205             Zanetti, Sig. Minio    male  20.0  restaurant staff        S
# 2206              Zarracchi, Sig. L.    male  26.0  restaurant staff        S
#
# ...

# %%
class_filter = RMS["class"] == "3rd"
class_filter
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2202    False
# 2203    False
# 2204    False
# 2205    False
# 2206    False
# Name: class, Length: 2207, dtype: bool

# %%
RMS_pass = RMS[(RMS["class"] == "3rd") | (RMS["class"] == "2nd") | (RMS["class"] == "1st")]
RMS_pass
# Out:
#                                 name  gender   age class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0   3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0   3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0   3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0   3rd        S
# ...                              ...     ...   ...   ...      ...
# 1314          Yvois, Miss. Henriette  female  24.0   2nd        S
# 1315       Zakarian, Mr. Mapriededer    male  22.0   3rd        C
# 1316             Zakarian, Mr. Ortin    male  27.0   3rd        C
# 1317               Zenni, Mr. Philip    male  25.0   3rd        C
# 1318             Zimmermann, Mr. Leo    male  29.0   3rd        S
#
#             country  ticketno     fare  sibsp  parch survived
# 0     United States    5547.0   7.1100    0.0    0.0       no
# ...

# %% [markdown]
# ##Plotting

# %%
female_filter = RMS["gender"] == "female"
female_filter
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 2202    False
# 2203    False
# 2204    False
# 2205    False
# 2206    False
# Name: gender, Length: 2207, dtype: bool

# %%
female_filter_age = RMS[female_filter]["age"]
female_filter_age
# Out:
# 3       39.0
# 4       16.0
# 7       28.0
# 12      40.0
# 14      18.0
#         ...
# 2059    45.0
# 2069    22.0
# 2076    47.0
# 2143    36.0
# 2145    32.0
# Name: age, Length: 489, dtype: float64

# %%
sns.displot(data=RMS_pass, x="age", col="gender")

# %%
sns.displot(data=RMS_pass, x="age", hue="gender", kind="kde")

# %% [markdown]
# ##How does this differ by class?##

# %%
sns.displot(data=RMS_pass,x="age",hue="gender",col="class",kind="kde")
